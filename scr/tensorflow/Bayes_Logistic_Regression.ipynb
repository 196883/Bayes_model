# %% [markdown]
# # Bayes Logistic Regression by Edward

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Setting the input and output as following
# \begin{align}
# \mathcal{D} = \{(x_1,y_1),\cdots,(x_n,y_1)\}
# \end{align}
#
# Logistic Regression Model is defined as following:
#
# \begin{align}
# p &= \sigma(wx + b) \\
# y &\sim {\rm Bern}(p)
# \end{align}
#
# This means that output $y$ is generated by input $x$ based on sigmoid function and Bernoulli distribution ${\rm Bern}(p)$.

# %% [markdown]
# Lets Start Model Setting By Edward:

# %%
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

tfd = tfp.distributions
tfe = tf.contrib.eager
ed = tfp.edward2

tf.enable_eager_execution()
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
#Model Function
def logistic_regression(X):
    w = ed.Normal(loc = tf.zeros(X.shape[1]), scale = 1, name = "coeffs")
    b = ed.Normal(loc = 0., scale = 1, name = "intercept")
    y = ed.Bernoulli(logits = tf.tensordot(X, w, [[1],[0]]) + b, name = "outcomes")
    return y

# %% [markdown]
# In Normal class in edward, each parameters are correspond to
#
#  loc = $\mu$
#
# scale = $\sigma$.
#
# Here, we set $w$ and $b$ by standard normal random variables.

# %% [markdown]
# $w$ is model parameter and here, we represent it as probability distribution.
#
# This means that the above logistic regression model is $\bf{Bayes\ model}$.

# %%
#Data set and Model running
num_features = 10
X = tf.random_normal([100,num_features])
y = logistic_regression(X)

# %% [markdown]
# ## See Posterior Distribution

# %% [markdown]
# In Bayes analysis, what we'd like to know is that $\bf{posterior\ distribution}$ of model parameter:
#
# $$
# p(w, b \mid \mathcal{D}).
# $$

# %%
def logistic_regression_posterior(num_features):
    posterior_w = ed.MultivariateNormalTriL(
        loc = tf.get_varialbe("w_loc", [num_featues]),
        scale_tril = tfp.trainable_distributions.tril_with_diag_softplus_and_shift(
            tf.get_variable("w_scale",[num_features * (num_features + 1) / 2])),
        name = "w_posterior")
    posterior_b = ed.Normal(
        loc = tf.get_varialbe("b_loc",[]),
        scale = tfp.trainable_distributions.tril_with_diag_softplus_and_shift(
            tf.get_variable("b_scale",[])),
        name = "b_posterior")
    return posterior_w, posterior_b

# %% [markdown]
# MultivariateNormalTriL:
#
#     Multivariate Normal distribution Class in Edward.
#
# tf.get_variable(variable name, variable size):
#
#     If variable was defined by tensorflow before code, get the variable.
#
#  tfp.trainable_distributions.tril_with_diga_softplus_and_shift(variable):
#
#     change vectors to lower-triangular scale matrices.

# %% [markdown]
# ## Set Prior Distribution

# %%
def set_prior_to_posterior_mean(f, *args, **kwargs):
    """Forms posterior predictions, setting each prior to its posterior mean."""
    name = kwargs.get("name")
    if name == "w":
        return posterior_w.distribution.mean()
    elif name == "b":
        return posterior_b.distribution.mean()
    return f(*args, **kwargs)

with ed.interception(set_prior_to_posterior_mean):
    predictions = logistic_regression(X)

# %% [markdown]
# ## Log Likehood Function

# %%
#data
X = tf.random_normal([100,55])
y = tf.random_uniform([100], minval = 0, maxval = 2, dtype = tf.int32)

#Log Likehood Finction
log_joint = ed.make_log_joint_fn(logistic_regression)

# %%
def target_log_prob_fn(w,b):
    return log_joint(X, w=w, b=b, y=y)

# %% [markdown]
# ## MCMC Processing

# %%
hmc_kernel = tfp.mcmc.HamiltonianMonteCarlo(
    target_log_prob_fn=target_log_prob_fn,
    step_size=0.1,
    num_leapfrog_steps=5)

# %%
states, kernel_results = tfp.mcmc.sample_chain(
    num_results=1000,
    current_state=[tf.random_normal([55]), tf.random_normal([])],
    kernel=hmc_kernel,
    num_burnin_steps=500)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-28-cec515aa9993> in <module>()
#       3     current_state=[tf.random_normal([55]), tf.random_normal([])],
#       4     kernel=hmc_kernel,
# ----> 5     num_burnin_steps=500)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/sample.py in sample_chain(num_results, current_state, previous_kernel_results, kernel, num_burnin_steps, num_steps_between_results, parallel_iterations, name)
#     233
#     234     if previous_kernel_results is None:
# --> 235       previous_kernel_results = kernel.bootstrap_results(current_state)
#     236
#     237     return tf.scan(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/hmc.py in bootstrap_results(self, init_state)
#     516   def bootstrap_results(self, init_state):
#     517     """Creates initial `previous_kernel_results` using a supplied `state`."""
# --> 518     kernel_results = self._impl.bootstrap_results(init_state)
#     519     if self.step_size_update_fn is not None:
#     520       step_size_assign = self.step_size_update_fn(self.step_size, None)  # pylint: disable=not-callable
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/metropolis_hastings.py in bootstrap_results(self, init_state)
#     262         name=mcmc_util.make_name(self.name, 'mh', 'bootstrap_results'),
#     263         values=[init_state]):
# --> 264       pkr = self.inner_kernel.bootstrap_results(init_state)
#     265       if not has_target_log_prob(pkr):
#     266         raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/hmc.py in bootstrap_results(self, init_state)
#     685           init_target_log_prob,
#     686           init_grads_target_log_prob,
# --> 687       ] = mcmc_util.maybe_call_fn_and_grads(self.target_log_prob_fn, init_state)
#     688       return UncalibratedHamiltonianMonteCarloKernelResults(
#     689           log_acceptance_correction=tf.zeros_like(init_target_log_prob),
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/util.py in maybe_call_fn_and_grads(fn, fn_arg_list, result, grads, check_non_none_grads, name)
#     235     fn_arg_list = (list(fn_arg_list) if is_list_like(fn_arg_list)
#     236                    else [fn_arg_list])
# --> 237     result, grads = _value_and_gradients(fn, fn_arg_list, result, grads)
#     238     if not all(r.dtype.is_floating
#     239                for r in (result if is_list_like(result) else [result])):  # pylint: disable=superfluous-parens
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/mcmc/util.py in _value_and_gradients(fn, fn_arg_list, result, grads, name)
#     183
#     184     if result is None:
# --> 185       result = fn(*fn_arg_list)
#     186       if grads is None and tf.executing_eagerly():
#     187         # Ensure we disable bijector cacheing in eager mode.
#
# <ipython-input-25-4ac3fe1f0e3b> in target_log_prob_fn(w, b)
#       1 def target_log_prob_fn(w,b):
# ----> 2     return log_joint(X, w=w, b=b, y=y)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/edward2/program_transformations.py in log_joint_fn(*args, **kwargs)
#     218     model_kwargs = _get_function_inputs(model, kwargs)
#     219     with interception(interceptor):
# --> 220       model(*args, **model_kwargs)
#     221     log_prob = sum(log_probs)
#     222     return log_prob
#
# <ipython-input-16-0cab54e793e2> in logistic_regression(X)
#       1 def logistic_regression(X):
# ----> 2     w = ed.Normal(loc = tf.zeros(X.shape[1]), scale = 1, name = "coeffs")
#       3     b = ed.Normal(loc = 0., scale = 1, name = "intercept")
#       4     y = ed.Bernoulli(logits = tf.tensordot(X, w, [[1],[0]]) + b, name = "outcomes")
#       5     return y
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/edward2/interceptor.py in func_wrapped(*args, **kwargs)
#     191   def func_wrapped(*args, **kwargs):
#     192     with get_next_interceptor() as interceptor:
# --> 193       return interceptor(func, *args, **kwargs)
#     194
#     195   return func_wrapped
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_probability/python/edward2/program_transformations.py in interceptor(rv_constructor, *rv_args, **rv_kwargs)
#     208       if value is None:
#     209         raise LookupError("Keyword argument specifying value for {} is "
# --> 210                           "missing.".format(rv_name))
#     211       rv_kwargs["value"] = value
#     212
#
# LookupError: Keyword argument specifying value for coeffs is missing.

# %% [markdown]
# ***Not Worked Well***
